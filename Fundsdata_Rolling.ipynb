# %% [markdown]
# <a href="https://colab.research.google.com/github/VandanasBorate/Machine_Learning_Algorithms/blob/main/Fundsdata_Rolling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymysql
# !pip install sqlalchemy
# !pip install --pre SQLAlchemy
# !pip install quandl
# !pip install mysql-connector-python
import pymysql
import pandas as pd
import quandl as qd
import time
import numpy as np
import datetime
from dateutil.relativedelta import relativedelta
import mysql.connector

# %%
import pymysql
import pandas as pd
import quandl as qd
import time
import numpy as np
import datetime
from dateutil.relativedelta import relativedelta
import warnings
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine
import sqlalchemy

# %%
connection = mysql.connector.connect(host='investtrestore.cvmmgrjdemrn.ap-south-1.rds.amazonaws.com',
                                    database='fund_database',
                                    user='admin',
                                    password='iNVESTT1729')
cursor = connection.cursor()
# create Engine
engine = create_engine(
  'mysql+pymysql://admin:iNVESTT1729@investtrestore.cvmmgrjdemrn.ap-south-1.rds.amazonaws.com:3306/fund_database')

# %%
cursor.execute("SELECT * FROM fund_database.funds_db")
fund_data = cursor.fetchall()
funds = pd.DataFrame(fund_data, columns=cursor.column_names)
funds.drop(columns=['id'], inplace=True)
# fund_df .drop(columns=['code'], inplace=True)
funds =funds.sort_values(by='date', ascending=True)
funds  =funds.set_index('date')

# %%
codes_f = funds['code'].unique().tolist()
codes_f

# %%
# fund_df1 =funds[funds['date'] >= pd.to_datetime('2021-09-03')]

# %%
connection = mysql.connector.connect(host='investtrestore.cvmmgrjdemrn.ap-south-1.rds.amazonaws.com',
                          database='advisor',
                          user='admin',
                          password='iNVESTT1729')
cursor = connection.cursor()
# create Engine
engine = create_engine(
'mysql+pymysql://admin:iNVESTT1729@investtrestore.cvmmgrjdemrn.ap-south-1.rds.amazonaws.com:3306/advisor')

# %%
sql_query = '''
SELECT Code,rolling, MAX(start_dates) AS max_date
FROM advisor.rollingdata
WHERE rolling = 1
GROUP BY Code;
'''

# Execute the SQL query
cursor.execute(sql_query)

# Fetch all the results
results = cursor.fetchall()
fund = pd.DataFrame(results, columns=cursor.column_names)
fund =fund.sort_values(by='max_date', ascending=True)

# %%
fund
# Out:
#         Code  rolling   max_date
# 148   101699        1 2011-12-28
# 1219  128751        1 2015-11-03
# 407   109940        1 2015-11-25
# 1548  141923        1 2018-03-28
# 1549  141924        1 2018-03-28
# ...      ...      ...        ...
# 1769  147193        1 2022-04-23
# 1770  147196        1 2022-04-23
# 127   101408        1 2022-04-23
# 419   111704        1 2022-04-23
# 0       None        1 2023-04-21
#
# [1957 rows x 3 columns]

# %%
fund = fund.dropna()

# %%
fund
# Out:
#         Code  rolling   max_date
# 148   101699        1 2011-12-28
# 1219  128751        1 2015-11-03
# 407   109940        1 2015-11-25
# 1548  141923        1 2018-03-28
# 1549  141924        1 2018-03-28
# ...      ...      ...        ...
# 837   119415        1 2022-04-23
# 1769  147193        1 2022-04-23
# 1770  147196        1 2022-04-23
# 127   101408        1 2022-04-23
# 419   111704        1 2022-04-23
#
# [1956 rows x 3 columns]

# %%
codes = fund['Code'].unique().tolist()
codes

# %%
len(codes)
# Out:
# 1956

# %%
# for code in codes:
#   stime = time.time()
#   print(code)
#   fund_df = fund[fund['Code']== code]

#   fund_df = fund_df.sort_index(ascending=True)
#   print(fund_df)

# %%
codes = fund['Code'].unique().tolist()
codes

# %%
len(codes)
# Out:
# 548

# %%
# codes =['101830',
#  '101818',
#  '101806',]
 
 
data = []
for code in codes:
  stime = time.time()
  print(code)
  fund_df = funds[funds['code']==int(code)]
  fund_df = fund_df.sort_index(ascending=True)
  # print(fund_df)
  fund_start_date= None
  fund_end_date = funds.index[-1]
  fund_df2 = fund[fund['Code']== code]
  # print(fund_df2)
 
  for d in fund_df2['max_date']:
     if d in fund_df.index:
      fund_start_date = fund_df[fund_df.index == d].index[0]
      fundf = fund_df.loc[fund_start_date:fund_end_date] 
      # print(fundf)
      data.append(fundf)
# Out:
# 101699
# 128751
# 109940
# 141923
# 141924
# 120830
# 120845
# 140220
# 147217
# 144994
# 139823
# 121158
# 121153
# 116424
# 119143
# 133713
# 133714
# 140333
# 134109
# 134110
# 146047
# 144658
# 144784
# 119279
# 119277
# 119275
# 119779
# 115882
# 112126
# 147647
# 117691
# 119252
# 123654
# 123651
# 119602
# 112293
# 147648
# 119271
# 119028
# 108202
# 120186
# 106597
# 106441
# 106370
# 117620
# 130493
# 130492
# 140328
# 140327
# 129438
# 140296
# 140295
# 148064
# 148063
# 118551
# 140274
# 140273
# 140256
# 140255
# 140243
# 140242
# 129440
# 118537
# 116633
# 132138
# 132140
# 133122
# 133307
# 132009
# 133184
# 133385
# 133386
# 132005
# 133486
# 133181
# 133054
# 131898
# 133051
# 132174
# 132178
# 132180
# 133036
# 133035
# 132186
# 132995
# 132989
# 132987
# 132183
# 132757
# 132756
# 132185
# 132998
# 120059
# 131865
# 130479
# 130472
# 130459
# 130450
# 130446
# 130314
# 130309
# 130206
# 130205
# 130050
# 130037
# 130496
# 129649
# 129312
# 129310
# 129223
# 129220
# ...

# %%
  for df in data:
    print(df)
    rollingdf = pd.DataFrame()
    fund_codes = []
    rolling = []
    start_dates = []
    start_values = []
    end_dates = []
    end_values = []
    changes = []
    for rol in [1]:
        for j in df.index:
    #       if j != old_last_date:
            nx_date = j - relativedelta(years=rol)
            d=0
            while d <= 7:
                try:
                    next_date = nx_date - datetime.timedelta(days=d)
                    present_val =float(df.loc[next_date]['nav'])
                    start_values.append(present_val)
                    next_val =float(df.loc[j]['nav'])
                    end_values.append(next_val)
                    change = round((((((next_val/present_val)) ** (1/rol)) - 1) * 100),2)
                    start_dates.append(next_date)
                    end_dates.append(j)
                    rolling.append(rol)
                    changes.append(change)
                    code = df.loc[next_date]['code']
                    fund_codes.append(code)
                    break
                except:
                    d += 1
     
    rollingdf['code'] = pd.Series(fund_codes)
    rollingdf['rolling'] = pd.Series(rolling)
    rollingdf['start_dates'] = pd.Series(start_dates)
    rollingdf['start_values'] = pd.Series(start_values)
    rollingdf['end_dates'] = pd.Series(end_dates)
    rollingdf['end_values'] = pd.Series(end_values)
    rollingdf['change'] = pd.Series(changes)
    print(rollingdf)
    # # rollingdf = rollingdf[1:]
    # rollingdf = rollingdf.set_index('start_dates')\
    #create Engine
    engine = create_engine(
    'mysql+pymysql://admin:iNVESTT1729@investtrestore.cvmmgrjdemrn.ap-south-1.rds.amazonaws.com:3306/fund_database')
    # Save the rollingdf to an Excel file
    # file_path = 'rolling_data.xlsx'  # Modify the file path as needed
    # with pd.ExcelWriter(file_path, mode='a', engine='openpyxl') as writer:
    #     rollingdf.to_excel(writer, sheet_name='Sheet1', header=False, index=False)

    # print("Data saved to Excel file:", file_path)


    rollingdf.to_sql('fundrolling1', con=engine, if_exists='append',index=False)
    
    # rollingdf.to_excel('rolling3.xlsx', header=False, index=False)
    # print("Time: ", time.time()-stime)
# Out:
# Streaming output truncated to the last 5000 lines.
# date
# 2020-09-03  24.8484  118780
# 2020-09-04  24.8652  118780
# 2020-09-07  24.8746  118780
# 2020-09-08  24.8615  118780
# 2020-09-09  24.8681  118780
# ...             ...     ...
# 2023-04-17  31.6772  118780
# 2023-04-18  31.6820  118780
# 2023-04-19  31.6857  118780
# 2023-04-20  31.7029  118780
# 2023-04-21  31.7110  118780
#
# [639 rows x 2 columns]
#          code  rolling start_dates  start_values  end_dates  end_values  \
# 0    118780.0        1  2020-09-03       24.8484 2021-09-03     28.9156
# 1    118780.0        1  2020-09-04       24.8652 2021-09-06     28.9291
# 2    118780.0        1  2020-09-07       24.8746 2021-09-07     28.9269
# 3    118780.0        1  2020-09-08       24.8615 2021-09-08     28.9396
# 4    118780.0        1  2020-09-09       24.8681 2021-09-09     28.9478
# ..        ...      ...         ...           ...        ...         ...
# ...

# %%
for df in data:
    print(df)
    rollingdf = pd.DataFrame()
    fund_codes = []
    rolling = []
    start_dates = []
    start_values = []
    end_dates = []
    end_values = []
    changes = []
    for rol in [3]:
        for j in df.index:
            nx_date = j - relativedelta(years=rol)
            d = 0
            while d <= 7:
                try:
                    next_date = nx_date - datetime.timedelta(days=d)
                    present_val = float(df.loc[next_date]['nav'])
                    start_values.append(present_val)
                    next_val = float(df.loc[j]['nav'])
                    end_values.append(next_val)
                    change = round((((next_val / present_val) ** (1 / rol)) - 1) * 100, 2)
                    start_dates.append(next_date)
                    end_dates.append(j)
                    rolling.append(rol)
                    changes.append(change)
                    code = df.loc[next_date]['code']
                    fund_codes.append(code)
                    break
                except:
                    d += 1
     
    rollingdf['code'] = pd.Series(fund_codes)
    rollingdf['rolling'] = pd.Series(rolling)
    rollingdf['start_dates'] = pd.Series(start_dates)
    rollingdf['start_values'] = pd.Series(start_values)
    rollingdf['end_dates'] = pd.Series(end_dates)
    rollingdf['end_values'] = pd.Series(end_values)
    rollingdf['change'] = pd.Series(changes)
    print(rollingdf)
    
    # # Save the rollingdf to an Excel file
    # with pd.ExcelWriter(r'C:\Users\Dell\Documents\fundrolling3.xlsx', mode='a', engine='openpyxl') as writer:
    #     rollingdf.to_excel(writer, sheet_name='rolling3', header=False, index=False)
    with pd.ExcelWriter('fundrolling3.xlsx', mode='a', engine='openpyxl') as writer:
      rollingdf.to_excel(writer, sheet_name='rolling3', header=False, index=False)

    # # Save the rollingdf to MySQL database
    # engine = create_engine('mysql+pymysql://username:password@hostname:port/database')
    # rollingdf.to_sql('fundrolling3', con=engine, if_exists='append', index=False)

print("Data saved to Excel file.")
# Out:
#                 nav    code
# date
# 2009-12-28  14.0360  101699
# 2009-12-29  14.0372  101699
# 2009-12-30  14.0384  101699
# 2009-12-31  14.0397  101699
# 2010-01-01  14.0409  101699
# ...             ...     ...
# 2012-12-24  11.4360  101699
# 2012-12-25  11.4387  101699
# 2012-12-26  11.4413  101699
# 2012-12-27  11.4440  101699
# 2012-12-28  11.4467  101699
#
# [915 rows x 2 columns]
#        code  rolling start_dates  start_values  end_dates  end_values  change
# 0  101699.0        3  2009-12-28        14.036 2012-12-28     11.4467   -6.57
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-109-d88182ab62cc> in <cell line: 1>()
#      43     # with pd.ExcelWriter(r'C:\Users\Dell\Documents\fundrolling3.xlsx', mode='a', engine='openpyxl') as writer:
#      44     #     rollingdf.to_excel(writer, sheet_name='rolling3', header=False, index=False)
# ...

# %%
# for df in data:
#     print(df)
#     rollingdf = pd.DataFrame()
#     rolling = []
#     start_dates = []
#     start_values = []
#     end_dates = []
#     end_values = []
#     changes = []
#     fund_code = []

#     # df['nav'] = df['nav'].replace(to_replace=0, method='ffill')
#     for rol in[3]:
#         # print(rol)
#         for j in df.index:
#     #       if j != old_last_date:
#             # print(j)
#             nx_date = j + relativedelta(years=rol)
#             # print(nx_date)
#             d=0
#             while d <= 7:
#                 try:
#                     end_date = nx_date - datetime.timedelta(days=d)
#                     end_dates.append(end_date)
#                     # print(end_date)
#                     start_dates.append(j)
#                     # start =df.index[0]
#                     # s_year = start.year
#                     # start_year.append(s_year)
#                     # end = df.index[-1]
#                     # e_year = end.year
#                     # end_year.append(e_year)
#                     next_val = float(df.loc[end_date]['nav'])
#                     end_values.append(next_val)
#                     present_val =float(df.loc[j]['nav'])
#                     start_values.append(present_val)
#                     change = round((((((next_val/present_val)) ** (1/rol)) - 1) * 100),2)
#                     code = df.loc[end_date]['code']
#                     rolling.append(rol)
#                     changes.append(change)
#                     fund_code.append(code)
                    
                    
#                     break
#                 except:
#                     d += 1
      
#     rollingdf['code'] = pd.Series(fund_code)
#     rollingdf['rolling'] = pd.Series(rolling)
#     rollingdf['start_dates'] = pd.Series(start_dates)
#     rollingdf['start_values'] = pd.Series(start_values)
#     rollingdf['end_dates'] = pd.Series(end_dates)
#     rollingdf['end_values'] = pd.Series(end_values)
#     rollingdf['change'] = pd.Series(changes)
#     print(rollingdf)
   
#     # engine = create_engine(
#     #    'mysql+pymysql://admin:iNVESTT1729@investtrestore.cvmmgrjdemrn.ap-south-1.rds.amazonaws.com:3306/fund_database')
#     # rollingdf.head(1).to_sql('differencefundrolling', con=engine, if_exists='append',index=False)
# Out:
#                  nav    code
# date
# 2018-09-03  162.4234  102431
# 2018-09-04  160.1761  102431
# 2018-09-05  160.9193  102431
# 2018-09-06  164.3412  102431
# 2018-09-07  165.8943  102431
# ...              ...     ...
# 2023-04-17  278.3078  102431
# 2023-04-18  281.8310  102431
# 2023-04-19  282.8084  102431
# 2023-04-20  280.3331  102431
# 2023-04-21  281.6008  102431
#
# [1139 rows x 2 columns]
#          code  rolling start_dates  start_values  end_dates  end_values  \
# 0    102431.0        3  2018-09-03      162.4234 2021-09-03    316.3013
# 1    102431.0        3  2018-09-04      160.1761 2021-09-04    316.3013
# 2    102431.0        3  2018-09-04      160.9193 2021-09-03    316.3013
# 3    102431.0        3  2018-09-05      164.3412 2021-09-05    316.0665
# 4    102431.0        3  2018-09-05      165.8943 2021-09-04    313.5052
# ..        ...      ...         ...           ...        ...         ...
# ...

# %%
# for df in data:
#   print(df)
#   rollingdf = pd.DataFrame()
#   fund_codes = []
#   rolling = []
#   start_dates = []
#   start_values = []
#   end_dates = []
#   end_values = []
#   changes = []
#   for rol in [3]:
#       for j in df.index:
#   #       if j != old_last_date:
#           nx_date = j - relativedelta(years=rol)
#           d=0
#           while d <= 7:
#               try:
#                   next_date = nx_date - datetime.timedelta(days=d)
#                   present_val = df.loc[next_date]['nav']
#                   next_val = df.loc[j]['nav']
#                   change = round((((((next_val/present_val)) ** (1/rol)) - 1) * 100),2)
#                   start_dates.append(next_date)
#                   start_values.append(present_val)
#                   end_dates.append(j)
#                   end_values.append(next_val)
#                   rolling.append(rol)
#                   changes.append(change)
#                   fund_codes.append(code)
#                   break
#               except:
#                   d += 1
#     # except:
#     #   pass
#   rollingdf['code'] = pd.Series(fund_codes)
#   rollingdf['rolling'] = pd.Series(rolling)
#   rollingdf['start_dates'] = pd.Series(start_dates)
#   rollingdf['start_values'] = pd.Series(start_values)
#   rollingdf['end_dates'] = pd.Series(end_dates)
#   rollingdf['end_values'] = pd.Series(end_values)
#   rollingdf['change'] = pd.Series(changes)
#   print(rollingdf)
#   # # rollingdf = rollingdf[1:]
#   # rollingdf = rollingdf.set_index('start_dates')\
#    #create Engine
#   engine = create_engine(
#   'mysql+pymysql://admin:iNVESTT1729@investtrestore.cvmmgrjdemrn.ap-south-1.rds.amazonaws.com:3306/fund_database')


#   # rollingdf.to_sql('fundrolling3', con=engine, if_exists='append',index=False)
  
#   # rollingdf.to_csv('C:\\Users\\Dell\\Documents\\rolling3.csv', header=False, index=False)
#   # print("Time: ", time.time()-stime)
# Out:
#                 nav    code
# date
# 2009-12-28  14.0360  101699
# 2009-12-29  14.0372  101699
# 2009-12-30  14.0384  101699
# 2009-12-31  14.0397  101699
# 2010-01-01  14.0409  101699
# ...             ...     ...
# 2012-12-24  11.4360  101699
# 2012-12-25  11.4387  101699
# 2012-12-26  11.4413  101699
# 2012-12-27  11.4440  101699
# 2012-12-28  11.4467  101699
#
# [915 rows x 2 columns]
#      code  rolling start_dates  start_values  end_dates  end_values  change
# 0  119303        3  2009-12-28        14.036 2012-12-28     11.4467   -6.57
#                   nav    code
# date
# 2013-11-25  1405.5796  109940
# 2013-11-26  1405.8648  109940
# 2013-11-27  1406.1497  109940
# 2013-11-28  1406.4251  109940
# 2013-11-29  1406.6701  109940
# ...               ...     ...
# 2016-11-21  1705.3681  109940
# 2016-11-22  1705.6061  109940
# 2016-11-23  1705.8505  109940
# 2016-11-24  1706.1073  109940
# 2016-11-25  1706.3476  109940
#
# [903 rows x 2 columns]
# ...
